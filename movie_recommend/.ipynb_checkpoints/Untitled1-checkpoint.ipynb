# %%
import numpy as np
import pandas as pd
import json

# %%
meta = pd.read_csv('data/movies_metadata.csv')
meta.head()
# Out:
# C:\Users\bit\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
meta=meta[['id']]
meta=meta.rename(columns={'id':'store_id'})
meta.head()
# Out:
#   store_id
# 0      862
# 1     8844
# 2    15602
# 3    31357
# 4    11862

# %%
store=pd.read_csv('teamdata/teamproject_store.csv')
store.head()
# Out:
#    id          store_name  store_type_code store_type local_name  \
# 0   1  7th street(세븐스트리트)             1020   여관/기타숙박업       의정부시
# 1   2            HotelMGM             1020   여관/기타숙박업       의정부시
# 2   3                 I모텔             1020   여관/기타숙박업       의정부시
# 3   4              K-레브호텔             1020   여관/기타숙박업       의정부시
# 4   5               MUL모텔             1020   여관/기타숙박업       의정부시
#
#                     road_address   store_phone  latitude  logitude  \
# 0  경기도 의정부시 신흥로222번길 5-26 (의정부동)  031-871-7077   37.7363   127.045
# 1    경기도 의정부시 신흥로258번길 35 (의정부동)  031-837-7260   37.7394   127.045
# 2    경기도 의정부시 태평로108번길 29 (의정부동)  031-844-5671   37.7422   127.053
# 3   경기도 의정부시 호국로1332번길 67 (의정부동)             0   37.7410   127.052
# 4    경기도 의정부시 시민로132번길 27 (의정부동)  031-875-6060   37.7368   127.050
#
#    star_ranking  search_result_count
# 0             2                59385
# 1             5               119587
# 2             4                75740
# 3             2               106456
# 4             1               126974

# %%
city=store['local_name']=='의정부시'
store = store[city]
store.head()
# Out:
#    id          store_name  store_type_code store_type local_name  \
# 0   1  7th street(세븐스트리트)             1020   여관/기타숙박업       의정부시
# 1   2            HotelMGM             1020   여관/기타숙박업       의정부시
# 2   3                 I모텔             1020   여관/기타숙박업       의정부시
# 3   4              K-레브호텔             1020   여관/기타숙박업       의정부시
# 4   5               MUL모텔             1020   여관/기타숙박업       의정부시
#
#                     road_address   store_phone  latitude  logitude  \
# 0  경기도 의정부시 신흥로222번길 5-26 (의정부동)  031-871-7077   37.7363   127.045
# 1    경기도 의정부시 신흥로258번길 35 (의정부동)  031-837-7260   37.7394   127.045
# 2    경기도 의정부시 태평로108번길 29 (의정부동)  031-844-5671   37.7422   127.053
# 3   경기도 의정부시 호국로1332번길 67 (의정부동)             0   37.7410   127.052
# 4    경기도 의정부시 시민로132번길 27 (의정부동)  031-875-6060   37.7368   127.050
#
#    star_ranking  search_result_count
# 0             2                59385
# 1             5               119587
# 2             4                75740
# 3             2               106456
# 4             1               126974

# %%
store=store.rename(columns={'id':'store_id'})

# %%
meta.store_id = pd.to_numeric(meta.store_id, errors='coerce')
store.store_id=pd.to_numeric(store.store_id, errors='coerce')

# %%
data=pd.merge(store, meta, on='store_id', how='inner')
data.head()
# Out:
#    store_id store_name  store_type_code store_type local_name  \
# 0         2   HotelMGM             1020   여관/기타숙박업       의정부시
# 1         3        I모텔             1020   여관/기타숙박업       의정부시
# 2         5      MUL모텔             1020   여관/기타숙박업       의정부시
# 3         6        M호텔             1020   여관/기타숙박업       의정부시
# 4        11      관동여인숙             1020   여관/기타숙박업       의정부시
#
#                      road_address   store_phone  latitude  logitude  \
# 0     경기도 의정부시 신흥로258번길 35 (의정부동)  031-837-7260   37.7394   127.045
# 1     경기도 의정부시 태평로108번길 29 (의정부동)  031-844-5671   37.7422   127.053
# 2     경기도 의정부시 시민로132번길 27 (의정부동)  031-875-6060   37.7368   127.050
# 3  경기도 의정부시 시민로122번길 59-10 (의정부동)  031-862-6045   37.7356   127.049
# 4              경기도 의정부시 호국로1298번길  031-846-4240   37.7394   127.073
#
#    star_ranking  search_result_count
# 0             5               119587
# 1             4                75740
# 2             1               126974
# 3             3                93349
# 4             4               108754

# %%
rating=pd.read_csv('data/ratings_small.csv')
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
rating = rating[['userId', 'movieId', 'rating']]
rating=rating.rename(columns={'movieId':'store_id'})
rating.head()
# Out:
#    userId  store_id  rating
# 0       1        31     2.5
# 1       1      1029     3.0
# 2       1      1061     3.0
# 3       1      1129     2.0
# 4       1      1172     4.0

# %%
result_data=pd.merge(rating, data, on='store_id', how='inner')

result_data=result_data[['userId', 'store_id', 'rating']]
result_data.sort_values(by=['userId'], axis=0, inplace=True)


result_data.head()
# Out:
#      userId  store_id  rating
# 0         1      1371     2.5
# 182       1      2294     2.0
# 140       1      2193     2.0
# 93        1      2105     4.0
# 47        1      1405     1.0

# %%
result_data.to_csv("resultData.csv", index=False, header=False)
